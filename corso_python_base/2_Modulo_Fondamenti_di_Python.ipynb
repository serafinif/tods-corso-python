# %% [markdown]
# # 📘 Modulo 2 – Fondamenti di Python
#
# ## 🎯 Obiettivi del modulo
# - Comprendere variabili e tipi di dato primitivi: `int`, `float`, `str`, `bool`.
# - Eseguire conversioni di tipo (cast) in modo sicuro.
# - Usare input/output e formattare stringhe in più modi.
# - Conoscere operatori aritmetici, logici e di confronto.
# - Capire la differenza tra tipi mutabili e immutabili (concetto intermedio).
# - Lavorare in Jupyter Notebook con celle di **Markdown** e **Codice**.
# - Svolgere esercizi guidati con **soluzioni visibili e commentate**.

# %% [markdown]
# ## 💻 Introduzione a Jupyter Notebook
#
# - Le celle **Markdown** servono per **testo, spiegazioni, immagini, formule**.
# - Le celle **Code** eseguono **Python**.
# - Usa `Shift+Enter` per eseguire una cella e passare alla successiva.
# - Puoi **ri-eseguire** una cella per aggiornare i risultati.
#
# > Suggerimento: mantieni il notebook pulito, rinomina i titoli e usa sezioni brevi.

# %% [markdown]
# ## 🔤 Variabili e tipi di dato
#
# In Python **non serve dichiarare il tipo**: il tipo si deduce dal valore assegnato.

# %%
# Esempi di variabili e tipi primitivi
intero = 42              # int
reale = 3.1415           # float
testo = "Ciao Python!"   # str
vero = True              # bool

print(type(intero), intero)
print(type(reale), reale)
print(type(testo), testo)
print(type(vero), vero)

# %% [markdown]
# ### Osservazioni
# - `int`: numeri interi (possono essere arbitrariamente grandi).
# - `float`: numeri decimali in **floating point** (attenzione a piccole imprecisioni).
# - `str`: stringhe (testo, sequenze di caratteri).
# - `bool`: valori logici `True` o `False`.

# %% [markdown]
# ## 🔁 Conversioni di tipo (cast)
#
# Usiamo le funzioni built-in: `int()`, `float()`, `str()`, `bool()`.

# %%
# Esempi di cast esplicito
x = "123"
y = "3.5"
print(int(x), type(int(x)))      # '123' -> 123
print(float(y), type(float(y)))  # '3.5' -> 3.5
print(str(99), type(str(99)))    # 99 -> '99'

# Attenzione: il cast può fallire
try:
    print(int("12.3"))
except ValueError as e:
    print("Errore nel cast:", e)

# %% [markdown]
# ## ⌨️ Input/Output e formattazione stringhe
#
# ### 🔹 `input()`
# - Legge **una riga di testo** da tastiera (termina con `Invio`).
# - Restituisce **sempre una stringa** (`str`).
# - Puoi specificare un messaggio di prompt opzionale.

# %%
nome = input("Come ti chiami? ")
print("Ciao", nome)

# %% [markdown]
# Per leggere numeri, devi **convertire** il risultato:

# %%
eta = int(input("Quanti anni hai? "))
pi = float(input("Inserisci il valore di pi greco: "))

# %% [markdown]
# ### 🔹 `print()`
#
# - Stampa uno o più elementi separati da spazi (di default).
# - Aggiunge automaticamente un a capo alla fine (\n).

# %%
print("Ciao", nome, "hai", eta, "anni")

# %% [markdown]
# Parametri utili:

# %%
print("A", "B", "C", sep="-")     # A-B-C → separatore personalizzato
print("Fine", end="!")            # Fine! → senza andare a capo

# %% [markdown]
# Python offre **tre modi principali** per formattare stringhe:
#
# 1. **f-string** (moderno, introdotto in Python 3.6)
# 2. **`str.format()`**
# 3. **Operatore `%`** (stile “printf”, storico)
#
# ### 🔹 1. f-string (consigliate)
#
# **Sintassi:**
# ```python
# f"Testo {espressione:spec} altro testo"
# ```

# %%
nome, anni, pi = "Ada", 36, 3.14159265
print(f"Ciao {nome}, hai {anni} anni. Pi ≈ {pi:.3f}")

# %% [markdown]
# Caratteristiche principali:
#
# - Leggibile e veloce
# - Permette espressioni Python direttamente all’interno
# - Usa la format mini-language moderna
#
# Altri esempi:

# %%
print(f"{anni:04d}")          # 0036 → padding con zeri
print(f"{1234567:,}")         # 1,234,567 → separatore migliaia (stile US)
print(f"{0.125:.2%}")         # 12.50% → formato percentuale
print(f"{nome=}")             # nome='Ada' → utile per debug

# %% [markdown]
# ✅ **Quando usarle:**
#
# Quasi sempre nel codice moderno (leggibilità, efficienza, flessibilità).

# %% [markdown]
# ### 🔹 2. Metodo .format()
#
# **Sintassi:**
# ```python
# "Testo {indice_o_nome:spec}".format(valori)
# ```
#
# **Esempio:**

# %%
# str.format()
print("Ciao {}, hai {} anni. Pi ≈ {:.3f}".format(nome, anni, pi))

# %%
print("Ciao {0}, hai {1} anni. Pi ≈ {2:.3f}".format(nome, anni, pi))
print("Hex: {n:#x}  Bin: {n:#b}".format(n=255))

# %% [markdown]
# **Caratteristiche:**
#
# - Stessa mini-language delle f-string
# - Puoi riusare la stringa modello (utile in logging o i18n)
# - Supporta nomi, indici, e riordino dei parametri
#
# ✅ **Quando usarlo:**
#
# Quando non puoi usare f-string (es. stringhe predefinite o riutilizzate).

# %% [markdown]
# ### 🔹 Operatore % (stile printf, storico)
#
# Lo stile “**C-like**”, compatibile con vecchio codice.
# È meno flessibile, ma ancora supportato.
#
# ✅ **Struttura generale**
# ```python
# "%[flags][width][.precision]type" % valore_o_tupla
# ```
#
# **Esempio base:**

# %%
# Operatore % (storico)
print("Ciao %s, hai %d anni. Pi ≈ %.3f" % (nome, anni, pi))

# %% [markdown]
# 📜 **Tipi più comuni**
#
# | Tipo       | Significato                         | Esempio                        |
# | ---------- | ----------------------------------- | ------------------------------ |
# | `%s`       | Stringa (usa `str()`)               | `"%s" % "Ada"` → `Ada`         |
# | `%r`       | Rappresentazione interna (`repr()`) | `"%r" % "Ada"` → `'Ada'`       |
# | `%d`, `%i` | Intero decimale                     | `"%d" % 42` → `42`             |
# | `%f`       | Float (fixed-point)                 | `"%.2f" % 3.14` → `3.14`       |
# | `%e`       | Notazione scientifica               | `"%.1e" % 1234` → `1.2e+03`    |
# | `%x`, `%X` | Esadecimale                         | `"%x" % 255` → `ff`            |
# | `%o`       | Ottale                              | `"%o" % 8` → `10`              |
# | `%c`       | Singolo carattere (da int o char)   | `"%c" % 65` → `A`              |
# | `%%`       | Percentuale letterale               | `"Sconto 10%%"` → `Sconto 10%` |

# %% [markdown]
# ⚙️ **Flag disponibili**
#
# | Flag | Effetto                                        | Esempio                            |
# | ---- | ---------------------------------------------- | ---------------------------------- |
# | `-`  | Allinea a sinistra                             | `"%-10s" % "Ada"` → `'Ada       '` |
# | `+`  | Mostra sempre il segno                         | `"%+d" % 3` → `+3`                 |
# | ` `  | Spazio come segno positivo                     | `"% d" % 3` → `' 3'`               |
# | `0`  | Padding con zeri                               | `"%05d" % 42` → `00042`            |
# | `#`  | Forma alternativa (`0x`, `0o`, punto decimale) | `"%#x" % 255` → `0xff`             |
#
# 🔢 **Width e precisione**
#
# - **Width** → larghezza minima del campo
# - **Precisione:**
#     - per **float** → cifre decimali
#     - per **stringhe** → numero massimo di caratteri
#
# **Esempi:**

# %%
print("|%10s|" % "Ada")     # |       Ada|
print("|%-10s|" % "Ada")    # |Ada       |
print("|%08.2f|" % 3.5)     # |00003.50|
print("|%.3s|" % "Python")  # |Pyt|

# %% [markdown]
# 🧮 **Sequenze di valori**
#
# **Con tuple:**

# %%
"%s ha %d anni" % ("Ada", 36)

# %% [markdown]
# **Con dizionario:**

# %%
"%(nome)s ha %(anni)d anni" % {"nome": "Ada", "anni": 36}

# %% [markdown]
# 🔸 **Escape del simbolo %**

# %%
sconto = 10
print("Sconto %d%%" % sconto)  # Sconto 10%

# %% [markdown]
# ⚠️ **Limiti dello stile %**
#
# - Nessun supporto per separatori di migliaia o underscore (_)
# - Nessun allineamento avanzato (<^>)
# - Errori se i tipi non corrispondono
# - Non adatto a numeri complessi o decimal.Decimal
# - Meno sicuro con input esterni (rischio format injection)

# %% [markdown]
# 🧠 **Confronto rapido**

# %%
n = 1234567.8912

# f-string (moderno)
f"{n:,.2f}"            # 1,234,567.89
f"{n:=+12.2f}"         # +  1234567.89

# str.format()
"{:>12.2f}".format(n)  # allineato a destra
"{:,.2f}".format(n)    # separatore migliaia

# Operatore %
"%12.2f" % n           # campo largo 12, 2 decimali
"%#x" % 255            # 0xff
"%.0f%%" % (0.123*100) # 12%

# %% [markdown]
# 📋 **Consigli pratici**
#
# | Caso d’uso                                 | Metodo consigliato              |
# | ------------------------------------------ | ------------------------------- |
# | Codice moderno, leggibile                  | ✅ **f-string**                  |
# | Stringa riutilizzata o con indici dinamici | ✅ **`.format()`**               |
# | Codice legacy o snippet C-like             | ⚙️ **`%`** (solo se necessario) |

# %% [markdown]
# ## ➕ Operatori aritmetici, logici e di confronto
#
# - **Aritmetici**: `+ - * / // % **`

# %%
a, b = 7, 3
print("Aritmetici:")
print("a+b =", a+b, "| a-b =", a-b, "| a*b =", a*b, "| a/b =", a/b)
print("a//b =", a//b, "(divisione intera) | a%b =", a%b, "(resto) | a**b =", a**b, "(potenza)")

# %% [markdown]
# - **Confronto**: `== != < <= > >=`

# %%
print("\nConfronto:")
print("a == b?", a == b)
print("a != b?", a != b)
print("a > b?", a > b)

# %% [markdown]
# - **Logici**: `and or not`

# %%
print("\nLogici:")
x, y = True, False
print("x and y ->", x and y)
print("x or y  ->", x or y)
print("not x   ->", not x)

# %% [markdown]
# ### 🔬 Nota sui `float`
# I `float` sono in **virgola mobile binaria**. Piccole imprecisioni sono normali:

# %%
print(0.1 + 0.2)      # 0.30000000000000004
print(round(0.1 + 0.2, 2))  # Soluzione pratica: arrotondare quando serve

# %% [markdown]
# ## 🧠 Tipi mutabili vs immutabili (intermedio)
#
# - **Immutabili**: `int`, `float`, `bool`, `str`, `tuple`.
#   Assegnare un nuovo valore crea un **nuovo oggetto**.
# - **Mutabili**: `list`, `dict`, `set`.
#   Le modifiche avvengono **in place** anche assegnando un nuovo valore.

# %%
# Esempio di immutabilità
a = 5
b = a
a = 10
print("a =", a)  # 10
print("b =", b)  # 5

# %%
# Esempio di mutabilità
lista = [1, 2, 3]
alias = lista           # alias fa riferimento allo stesso oggetto
alias.append(4)
print(lista)            # [1, 2, 3, 4] -> modificata anche 'lista'

# Per copiare una lista (shallow copy):
copia = lista.copy()
copia.append(5)
print("lista:", lista, "| copia:", copia)

# %% [markdown]
# # 🧪 Esercizi pratici (con soluzioni)
#
# ## 1️⃣ Calcolatrice base
#
# **✍️ Consegna:**
#
# chiedere due numeri all'utente e stampare le quattro operazioni: `+ - * /`.
#
# > Suggerimento: ricorda di convertire l'input a `float` o `int`.

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .

# %%
# ✅ Soluzione 

x = int(input ("Dammi il primo numero"))
y = int(input ("Dammi il secondo numero"))
somma = x + y
sottrazione = x - y
moltiplicazione = x * y
divisione = x / y

print(f"Somma = {somma} ,Sottrazione = {sottrazione} ,Moltiplicazione = {moltiplicazione} ,Divisione = {divisione:.3f}")
# Out:
#   Cell In[7], line 9
#     print (f"X="x,"Y="y, sep=" , ")
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## 2️⃣ Trasformazione Celsius → Fahrenheit
#
# **✍️ Consegna:**
#
# Scrivere un programma che preso in input c = temperatura in Celsius restituisca F temperatura in Fahrenheit
#
# Formula: `F = C * 9/5 + 32`

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .

# %%
# ✅ Soluzione 

temperaturaC=float(input("Inserisci la temperatura in gradi celsius"))
temperaturaF= temperaturaC * 9/5 +32
print ("Temperatura in Fahrenheit",temperaturaF)
# Out:
# Temperatura in Fahrenheit 50.0

# %% [markdown]
# ## 3️⃣ In che anno compirai 100 anni?
#
# **✍️ Consegna:**
#
# Scrivere un programma che chieda l'età all'utente e **calcola l'anno** in cui compirà 100 anni.
#
# **suggerimento:**
# ```python
# from datetime import datetime
# anno_corrente = datetime.now().year
# ```

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .

# %%
# ✅ Soluzione 
eta=int(input("Dimmi la tua età"))
from datetime import datetime
anno_corrente = datetime.now().year
anno_100 = (anno_corrente + 100)-eta
print ("Compirai 100 anni nell' anno", anno_100)
# Out:
# Compirai 100 anni nell' anno 2097

# %% [markdown]
# ## 4️⃣ Calcolo del costo medio giornaliero
#
# **✍️ Consegna:**
#
# Scrivi un programma che:
# 1. Chieda all’utente **quanto ha speso in totale** in una settimana (`float`).
# 2. Calcoli e stampi la **spesa media giornaliera**.
# 3. Formatti il risultato con **due decimali** usando un’`f-string`.
#
# > 💡 Suggerimento: la settimana ha 7 giorni, ma potresti voler gestire in futuro anche settimane “parziali”.

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .

# %%
# ✅ Soluzione 
spesatotale=float(input("Quanto hai speso in una settimana?"))
giornisettimana=int(7)
spesamediadaily=float(spesatotale/giornisettimana)
print(f"La spesa media è {spesamediadaily:.2f}€ al giorno")
# Out:
# La spesa media è 10.00€ al giorno

# %% [markdown]
# ## 5️⃣ Valutazione del budget personale
#
# **✍️ Consegna:**
#
# Scrivi un programma che:
# 1. Chieda all’utente **le entrate** e **le spese** del mese.
# 2. Calcoli il **saldo mensile**.
# 3. Stampi un messaggio diverso in base al saldo:
#    - 🔴 Se negativo → “Attenzione! Hai speso più del dovuto.”
#    - 🟡 Se tra 0 e 100 → “Sei quasi in pari, occhio alle spese.”
#    - 🟢 Se maggiore di 100 → “Ottima gestione del budget!”
#
# > 💡 Usa condizioni `if/elif/else` e assicurati di convertire i valori in `float`.

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .

# %%
# ✅ Soluzione 
entrate= float(input("Quali sono le entrate?"))
uscite=float(input("Quali sono le uscite?"))
saldo=float(entrate-uscite)
if saldo<0:
    print(f"Non ok")
elif saldo<=100:
    print(f"Sei quasi in pari")
else:
    print(f"Ottima gestione del budget")
# Out:
# Non ok

# %% [markdown]
# ## 6️⃣ Tipi mutabili e immutabili
#
# **✍️ Consegna:**
#
# Crea un piccolo script per comprendere la differenza tra **mutabili** e **immutabili**:
#
# 1. Crea una variabile `a = 5` e una lista `numeri = [1, 2, 3]`.
# 2. Crea due copie: `b = a` e `lista2 = numeri`.
# 3. Modifica `a` e `numeri` (`a = 10`, `numeri.append(4)`).
# 4. Stampa i valori di `a`, `b`, `numeri`, e `lista2`.
# 5. Rifletti sul comportamento osservato: perché uno cambia e l’altro no?
#
# > 💡 I tipi immutabili (come `int`, `str`, `tuple`) creano nuove copie quando modificati,
# > mentre i mutabili (`list`, `dict`, `set`) si aggiornano “in place”.

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .

# %%
# ✅ Soluzione 
a=5
numeri=[1,2,3,]
b=a
lista2=numeri
a=10
numeri.append(4)
print(f"{a} {b} {numeri} {lista2}")
# Out:
# 10 5 [1, 2, 3, 4] [1, 2, 3, 4]

# %% [markdown]
# ## 7️⃣ Formattazione di output con stile
#
# **✍️ Consegna:**
#
# Scrivi un piccolo programma che, dati i seguenti valori:
#
# - `nome = "Ada"`
# - `anni = 36`
# - `pi = 3.14159265`
#
# stampi **tre righe diverse** con le seguenti modalità di formattazione:
#
# 1. 🔹 **f-string** → `Ciao Ada, hai 36 anni. Pi vale circa 3.142`
# 2. 🔹 **str.format()** → stessa frase, ma con sintassi `format()`
# 3. 🔹 **operatore %** → usa i simboli `%s`, `%d`, `%.3f`
#
# > 💡 Ricorda:
# > - `%s` → stringa
# > - `%d` → intero
# > - `%f` → numero decimale (`%.3f` → 3 cifre dopo la virgola)
# > - Usa `:.3f` nelle f-string e nel `.format()` per arrotondare Pi a 3 decimali.

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .

# %%
# ✅ Soluzione 
nome = "Ada"
anni = 36
pi = 3.14159265
print(f"Ciao {nome}, hai {anni} anni. Pi vale circa {pi:.3f}")
print("Ciao {}, hai {} anni. Pi vale circa {:.3f}".format(nome, anni, pi))
print("Ciao %s, hai %d anni. Pi vale circa %.3f" % (nome, anni, pi))
# Out:
# Ciao Ada, hai 36 anni. Pi vale circa 3.142
# Ciao Ada, hai 36 anni. Pi vale circa 3.142
# Ciao Ada, hai 36 anni. Pi vale circa 3.142

# %% [markdown]
# ## ✅ Conclusioni
#
# - Hai visto variabili, tipi primitivi e conversioni di tipo.
# - Hai usato `input()`/`print()` e diverse tecniche di formattazione.
# - Hai esplorato operatori aritmetici, logici e di confronto.
# - Hai introdotto il concetto di mutabilità.
# - Hai svolto esercizi pratici con soluzioni.
